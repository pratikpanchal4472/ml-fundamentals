# %%
# importing required packages
# data operation libraries

import numpy as np
import pandas as pd
# visualization libraries

import matplotlib.pyplot as plt
import seaborn as sns
# For regression
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

import numpy as np
import pandas as pd
from sklearn.linear_model import Lasso, Ridge
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# %%
dataset = pd.read_csv(r'dataset/Advertising.csv')

dataset
# Out:
#      Unnamed: 0     TV  Radio  Newspaper  Sales
# 0             1  230.1   37.8       69.2   22.1
# 1             2   44.5   39.3       45.1   10.4
# 2             3   17.2   45.9       69.3    9.3
# 3             4  151.5   41.3       58.5   18.5
# 4             5  180.8   10.8       58.4   12.9
# ..          ...    ...    ...        ...    ...
# 195         196   38.2    3.7       13.8    7.6
# 196         197   94.2    4.9        8.1    9.7
# 197         198  177.0    9.3        6.4   12.8
# 198         199  283.6   42.0       66.2   25.5
# 199         200  232.1    8.6        8.7   13.4
#
# [200 rows x 5 columns]

# %%
## Prepare the independent dataset
Data = dataset.drop(['Unnamed: 0'], axis=1)
Data
# Out:
#         TV  Radio  Newspaper  Sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3    9.3
# 3    151.5   41.3       58.5   18.5
# 4    180.8   10.8       58.4   12.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1    9.7
# 197  177.0    9.3        6.4   12.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   13.4
#
# [200 rows x 4 columns]

# %%
## Identify X & Y that is independant and dependant variable directly
X = Data[['TV', 'Radio', 'Newspaper']]
y = dataset.Sales

# %%
## Split between train and test 
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state = 1)

# %% [markdown]
# # 1. Subset Selection

# %% [markdown]
# # Forward Selection

# %%
from sklearn.feature_selection import SequentialFeatureSelector
from sklearn.linear_model import LinearRegression

lr = LinearRegression()

forward = SequentialFeatureSelector(
    lr,
    n_features_to_select=2,
    direction='forward'
)

forward.fit(X, y)
selected_forward = X.columns[forward.get_support()]
print("Forward Selection:", selected_forward.tolist())
# Out:
# Forward Selection: ['TV', 'Radio']

# %% [markdown]
# # Backward Selection

# %%
backward = SequentialFeatureSelector(
    lr,
    n_features_to_select=2,
    direction='backward'
)

backward.fit(X, y)
selected_backward = X.columns[backward.get_support()]
print("Backward Selection:", selected_backward.tolist())
# Out:
# Backward Selection: ['TV', 'Radio']

# %% [markdown]
# # Regularization

# %% [markdown]
# # -----------------------------------------------------
# # 3. Ridge Regression
# # -----------------------------------------------------

# %%
#creating a ridge regression object from scikit learn
ridge = Ridge(alpha=120.0) #alpha is regularization strength (λ).
ridge.fit(X_train, y_train)

ridge_pred = ridge.predict(X_test)
ridge_mse = mean_squared_error(y_test, ridge_pred)

print("=== Ridge Regression ===")
print("Coefficients:", ridge.coef_)
print("Intercept:", ridge.intercept_)
print("MSE:", ridge_mse)
print()
# Out:
# === Ridge Regression ===
# Coefficients: [0.04694806 0.17580726 0.00207333]
# Intercept: 2.9491922536164434
# MSE: 1.9404777394564063

# %% [markdown]
# # -----------------------------------------------------
# # 4. Lasso Regression
# # -----------------------------------------------------

# %%
# create an object of Lasso Regression model with regularization strength alpha = 0.1.
lasso = Lasso(alpha=0.01)
lasso.fit(X_train, y_train)

lasso_pred = lasso.predict(X_test)
lasso_mse = mean_squared_error(y_test, lasso_pred)

print("=== Lasso Regression ===")
print("Coefficients:", lasso.coef_)
print("Intercept:", lasso.intercept_)
print("MSE:", lasso_mse)
# Out:
# === Lasso Regression ===
# Coefficients: [0.04695111 0.17655104 0.00184   ]
# Intercept: 2.938505621130574
# MSE: 1.929387097542705

# %% [markdown]
# # Using credit card example

# %%
#importing all the required packages
import pandas as pd
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# %%
# Example: Credit.csv (ISLR)
df_credit = pd.read_csv(r"dataset/Credit.csv")
df_credit
# Out:
#       Income  Limit  Rating  Cards  Age  Education  Own Student Married  \
# 0     14.891   3606     283      2   34         11   No      No     Yes
# 1    106.025   6645     483      3   82         15  Yes     Yes     Yes
# 2    104.593   7075     514      4   71         11   No      No      No
# 3    148.924   9504     681      3   36         11  Yes      No      No
# 4     55.882   4897     357      2   68         16   No      No     Yes
# ..       ...    ...     ...    ...  ...        ...  ...     ...     ...
# 395   12.096   4100     307      3   32         13   No      No     Yes
# 396   13.364   3838     296      5   65         17   No      No      No
# 397   57.872   4171     321      5   67         12  Yes      No     Yes
# 398   37.728   2525     192      1   44         13   No      No     Yes
# 399   18.701   5524     415      5   64          7  Yes      No      No
#
#     Region  Balance
# 0    South      333
# 1     West      903
# 2     West      580
# ...

# %%
df_credit.dtypes
# Out:
# Income       float64
# Limit          int64
# Rating         int64
# Cards          int64
# Age            int64
# Education      int64
# Own              str
# Student          str
# Married          str
# Region           str
# Balance        int64
# dtype: object

# %%
df_credit.corr()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 df_credit.corr()
#
# File ~/Documents/iitd-aiml/Practices/mathsfoundation/.venv/lib/python3.13/site-packages/pandas/core/frame.py:13117, in DataFrame.corr(self, method, min_periods, numeric_only)
#   13115 cols = data.columns
#   13116 idx = cols.copy()
# > 13117 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   13119 if method == "pearson":
#   13120     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~/Documents/iitd-aiml/Practices/mathsfoundation/.venv/lib/python3.13/site-packages/pandas/core/frame.py:2081, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    2079 if dtype is not None:
#    2080     dtype = np.dtype(dtype)
# -> 2081 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    2082 if result.dtype is not dtype:
# ...

# %%
## Check for correlation and draw the heat-map
corr = df_credit.corr()
sns.heatmap(corr, vmax=1, vmin=-1, annot=True, cmap='GnBu')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[16], line 2
#       1 ## Check for correlation and draw the heat-map
# ----> 2 corr = df_credit.corr()
#       3 sns.heatmap(corr, vmax=1, vmin=-1, annot=True, cmap='GnBu')
#
# File ~/Documents/iitd-aiml/Practices/mathsfoundation/.venv/lib/python3.13/site-packages/pandas/core/frame.py:13117, in DataFrame.corr(self, method, min_periods, numeric_only)
#   13115 cols = data.columns
#   13116 idx = cols.copy()
# > 13117 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   13119 if method == "pearson":
#   13120     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~/Documents/iitd-aiml/Practices/mathsfoundation/.venv/lib/python3.13/site-packages/pandas/core/frame.py:2081, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    2079 if dtype is not None:
#    2080     dtype = np.dtype(dtype)
# ...

# %%
X = df_credit[['Income','Limit','Rating','Cards','Age','Education']]
y = df_credit['Balance']

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42
)

# %%
# ordinary linear regression

lr = LinearRegression().fit(X_train, y_train)
print("Linear RMSE:", mean_squared_error(y_test, lr.predict(X_test), squared=False))
print("Coefficients = ", lr.coef_)
print("Intercept = ", lr.intercept_)
print("\nRegression Coefficients:")
print(pd.Series(lr.coef_, index=X.columns))

# %%
# Ridge regression
ridge = Ridge(alpha=10)
ridge.fit(X_train, y_train)
print("Ridge RMSE:", mean_squared_error(y_test, ridge.predict(X_test), squared=False))
print("Coefficients = ", ridge.coef_)
print("Intercept = ", ridge.intercept_)
print("\nRidge Coefficients:")
print(pd.Series(ridge.coef_, index=X.columns))

# %%
# Lasso regression
lasso = Lasso(alpha=30.0)
lasso.fit(X_train, y_train)
print("Lasso RMSE:", mean_squared_error(y_test, lasso.predict(X_test), squared=False))
print("Coefficients = ", lasso.coef_)
print("Intercept = ", lasso.intercept_)
print("\Lasso Coefficients:")
print(pd.Series(lasso.coef_, index=X.columns))

# %%
from sklearn.preprocessing import LabelEncoder

# Sample data
data = {'Own': ['Yes', 'No', 'Yes', 'No'],
        'Student': ['No', 'Yes', 'Yes', 'No']}

import pandas as pd
df = pd.DataFrame(data)

# Initialize encoder
le = LabelEncoder()

# Apply to each column
df['Own_encoded'] = le.fit_transform(df['Own'])
df['Student_encoded'] = le.fit_transform(df['Student'])

print(df)

# %%
from sklearn.linear_model import LassoCV, RidgeCV

lasso_cv = LassoCV(cv=10).fit(X_train, y_train)
ridge_cv = RidgeCV(alphas=[0.1,1,10,100,200]).fit(X_train, y_train)

print(lasso_cv.alpha_)
print(ridge_cv.alpha_)

# %%
df5 = df_credit
df5

# %%
# Initialize encoder
le = LabelEncoder()

# Apply to each column
df5['Own_encoded'] = le.fit_transform(df5['Own'])
df5['Student_encoded'] = le.fit_transform(df5['Student'])

print(df5)

# %%
df6 = df_credit

# %%
df_encoded = pd.get_dummies(df6, columns=['Own', 'Student', 'Married', 'Region'], drop_first=True)
df_encoded
